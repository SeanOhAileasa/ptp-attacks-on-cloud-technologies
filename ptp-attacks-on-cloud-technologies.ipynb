# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/ptp-attacks-on-cloud-technologies/blob/main/README.md) >
#
# ## CompTIA PenTest+ - Course Material 2022
# ###### Topic: ``Attacks on Cloud Technologies``
# ***

# %% [markdown]
# Course material for the ``CompTIA PenTest+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Attacks on Cloud Technologies](#aa) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Credential Harvesting](#A) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Privilege Escalation Attacks](#B) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Account Takeover Attacks](#C) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Metadata Service Attacks](#D) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Asset Misconfigurations](#E) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Resource Exhaustion](#F) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Cloud Malware Injection Attacks](#G) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Denial of Service Attacks](#H) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Side-channel Attacks](#I) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Direct-to-Origin Attacks](#J) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Software Development Kit](#K) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ### [Course Summary](#L) <br/><br/>
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="aa"></a>
# ***
# ### Attacks on Cloud Technologies
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="A"></a>
# ***
# ### Credential Harvesting
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="B"></a>
# ***
# ### Privilege Escalation Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="C"></a>
# ***
# ### Account Takeover Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="D"></a>
# ***
# ### Metadata Service Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="E"></a>
# ***
# ### Cloud Asset Misconfigurations
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="F"></a>
# ***
# ### Cloud Resource Exhaustion
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="G"></a>
# ***
# ### Cloud Malware Injection Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="H"></a>
# ***
# ### Denial of Service Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="I"></a>
# ***
# ### Side-channel Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="J"></a>
# ***
# ### Direct-to-Origin Attacks
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="K"></a>
# ***
# ### Software Development Kit
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="L"></a>
# ***
# ### Course Summary
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;skillsoft, "Attacks on Cloud Technologies," [skillsoft.com](https://web.archive.org/web/20220403100053/https://www.skillsoft.com/), n.d..

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\SeanOhAileasa\AppData\Local\Temp\ipykernel_1624\1322614208.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
